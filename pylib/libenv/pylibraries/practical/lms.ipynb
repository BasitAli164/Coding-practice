# %% [markdown]
# # LMS Servey Data Preporcing

# %% [markdown]
# ### Import Lib

# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;

# %%
df=pd.read_csv('SIS Survey - Form Responses 1.csv')
df
# Out:
#               Timestamp              Email Address         Full Name  \
# 0    5/22/2025 13:14:33    dillu.parkash@gmail.com     Dilawar Abbas
# 1    5/22/2025 13:09:29  ghulamsaleem786@gmail.com    Ghulam Hussain
# 2     5/16/2025 5:19:33      mudassir237@yahoo.com     Mudassir Ali
# 3    5/22/2025 13:19:23      asim.oxygen@gmail.com    Muhammad Asim
# 4    5/22/2025 13:36:03   nazia.maryam@uobs.edu.pk      nazia maryam
# ..                  ...                        ...               ...
# 98   5/16/2025 17:04:34     aleebalti046@gmail.com     Zulfiqar Ali
# 99   5/22/2025 18:07:02        coder8820@gmail.com     kumail abbass
# 100  5/22/2025 22:20:02    mrmalang08569@gmail.com    Shahid Hussain
# 101  5/11/2025 20:57:13       iqbal.parvi@yaho.com             iqbal
# 102   7/9/2025 10:47:40   mhasnainsaqi88@gmail.com  Naveed ul hassan
#
#             Department Semester  \
# 0     Computer Science      NaN
# 1                   CS      NaN
# 2    Computer science       NaN
# 3    Computer science       NaN
# 4     computer science      NaN
# ..                 ...      ...
# 98                  CS      1st
# 99                bscs      5th
# 100                 Cs        5
# 101   computer science        0
# 102              BS AI     Fist
#
#     In your opinion, does the current information architecture (layout of pages, menus, and modules) support user goals effectively?    \
# 0                                                Agree
# 1                                              Neutral
# 2                                                Agree
# 3                                              Neutral
# 4                                                Agree
# ..                                                 ...
# 98                                               Agree
# 99                                            Disagree
# 100                                            Neutral
# 101                                            Neutral
# 102                                              Agree
#
#     Is the system responsive across devices (desktop, tablet, mobile)?  \
# 0                                 Partially responsive
# 1                                       Not responsive
# 2                                 Partially responsive
# 3                                 Partially responsive
# 4                                     Fully responsive
# ..                                                 ...
# 98                                Partially responsive
# 99                                      Not responsive
# 100                               Partially responsive
# 101                               Partially responsive
# 102                                   Fully responsive
#
#     Does the system follow any standardized design principles (e.g., consistency, feedback, error handling)?  \
# 0                                       To some extent
# 1                                                   No
# 2                                       To some extent
# 3                                       To some extent
# 4                                                   No
# ..                                                 ...
# 98                                          Don’t know
# 99                                                  No
# 100                                         Don’t know
# 101                                     To some extent
# 102                                                Yes
#
#     Are there redundant or unused features that should be deprecated or redesigned?    \
# 0                                                   No
# 1                                            main page
# 2                                                   No
# 3                                             No need.
# 4                                                   no
# ..                                                 ...
# 98                                                  No
# 99                                                 yes
# 100                                             e-book
# 101                                               quiz
# 102  Yes some outdated discussion forums and rarely...
#
#     Suggest one feature that would enhance the academic experience if added to the system.    \
# 0                                 Alumini Registration
# 1                                                  NaN
# 2    Must add feedback option. So we get the opinions
# 3                                                  NaN
# 4                                                   no
# ..                                                 ...
# 98                                                 NaN
# 99   libraries system should be online to read any ...
# 100               should have a learning streak treker
# 101                                                n?A
# 102          Al based personalized learning suggestion
#
#      ... How frequently do you interact with the SIS account system?   \
# 0    ...                                              Daily
# 1    ...                                              Daily
# 2    ...                                              Daily
# 3    ...                                              Daily
# 4    ...                                              Daily
# ..   ...                                                ...
# 98   ...                                             Weekly
# 99   ...                                       Occasionally
# 100  ...                                             Weekly
# 101  ...                                              Daily
# 102  ...                                             Weekly
#
#       Have you experienced performance issues (e.g., slow loading, timeouts) while using the system?    \
# 0                                         Occasionally
# 1                                         Occasionally
# 2                                         Occasionally
# 3                                           Frequently
# 4                                                Never
# ..                                                 ...
# 98                                        Occasionally
# 99                                        Occasionally
# 100                                       Occasionally
# 101                                       Occasionally
# 102                                              Never
#
#     From a user experience (UX) perspective, how would you rate the system's interface?   \
# 0                                    Moderately usable
# 1                                    Moderately usable
# 2                                    Moderately usable
# 3                                    Needs improvement
# 4                                    Needs improvement
# ..                                                 ...
# 98                                   Moderately usable
# 99                                   Needs improvement
# 100                                  Needs improvement
# 101                                  Moderately usable
# 102                                  Needs improvement
#
#     Which of the following modules do you actively use?   \
# 0                       Attendance Tracking, Timetable
# 1                                            Timetable
# 2                                  Attendance Tracking
# 3                                  Attendance Tracking
# 4                       Attendance Tracking, Timetable
# ..                                                 ...
# 98                                 Attendance Tracking
# 99     Attendance Tracking, Timetable, Fee Information
# 100                     Attendance Tracking, Timetable
# 101                                          Timetable
# 102                                          Timetable
#
#     Do you think the content modules (e.g., Notice Board, Events) are being actively maintained and updated?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 98                                               Maybe
# 99                                                  No
# 100                                                 No
# 101                                                 No
# 102                                                Yes
#
#     Announcements and notification (course update, deadlines, etc) should be included   \
# 0                                             Disagree
# 1                                                Agree
# 2                                              Neutral
# 3                                              Neutral
# 4                                                Agree
# ..                                                 ...
# 98                                               Agree
# 99                                   Strongly Disagree
# 100                                            Neutral
# 101                                              Agree
# 102                                           Disagree
#
#     Column 25   Status Column 25.1 @dropdown
# 0         NaN  Faculty         NaN       NaN
# 1         NaN  Faculty         NaN       NaN
# 2         NaN  Faculty         NaN       NaN
# 3         NaN  Faculty         NaN       NaN
# 4         NaN  Faculty         NaN       NaN
# ..        ...      ...         ...       ...
# 98        NaN  Student         NaN       NaN
# 99        NaN  Student         NaN       NaN
# 100       NaN  Student         NaN       NaN
# 101       NaN      NaN         NaN       NaN
# 102       NaN  Student         NaN       NaN
#
# [103 rows x 29 columns]

# %% [markdown]
# ## Ask Six Question to Yourself

# %%
df.shape
# Out:
# (103, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 29 columns):
#  #   Column                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                                               103 non-null    object
#  1   Email Address                                                                                                                           103 non-null    object
#  2   Full Name                                                                                                                               103 non-null    object
#  3   Department                                                                                                                              103 non-null    object
#  4   Semester                                                                                                                                95 non-null     object
#  5   In your opinion, does the current information architecture (layout of pages, menus, and modules) support user goals effectively?        103 non-null    object
#  6   Is the system responsive across devices (desktop, tablet, mobile)?                                                                      103 non-null    object
#  7   Does the system follow any standardized design principles (e.g., consistency, feedback, error handling)?                                103 non-null    object
#  8   Are there redundant or unused features that should be deprecated or redesigned?                                                         103 non-null    object
#  9   Suggest one feature that would enhance the academic experience if added to the system.                                                  81 non-null     object
#  10  Given that the system is accessible via specific IPs only (home & university), do you think this is a sufficient security mechanism?    103 non-null    object
#  11  Do you feel your login credentials and academic records are securely handled by the system?                                             103 non-null    object
#  12  Should additional layers of security be implemented (e.g., OTP, 2FA, CAPTCHA)?                                                          103 non-null    object
#  13  The system notify you if there is any unauthorized access or suspicious activity on your SIS account?                                   103 non-null    object
#  14   The system send you a notification whenever a teacher or instructor uploads a new assignment                                           103 non-null    object
#  15  How would you rate the software’s reliability and uptime?                                                                               103 non-null    object
#  16  Does the system provide error messages and validation feedback that help users recover from mistakes?                                   103 non-null    object
#  17  Do you think the system was developed with scalability in mind (e.g., handling load for growing students)?                              103 non-null    object
#  18  How effective is the system’s help/support documentation or assistance options?                                                         99 non-null     object
#  19  How frequently do you interact with the SIS account system?                                                                             103 non-null    object
#  20    Have you experienced performance issues (e.g., slow loading, timeouts) while using the system?                                        103 non-null    object
#  21  From a user experience (UX) perspective, how would you rate the system's interface?                                                     103 non-null    object
#  22  Which of the following modules do you actively use?                                                                                     103 non-null    object
#  23  Do you think the content modules (e.g., Notice Board, Events) are being actively maintained and updated?                                103 non-null    object
#  24  Announcements and notification (course update, deadlines, etc) should be included                                                       101 non-null    object
#  25  Column 25                                                                                                                               0 non-null      float64
#  26  Status                                                                                                                                  102 non-null    object
#  27  Column 25.1                                                                                                                             0 non-null      float64
#  28  @dropdown                                                                                                                               0 non-null      float64
# dtypes: float64(3), object(26)
# memory usage: 23.5+ KB

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                   0
# Email Address                                                                                                                               0
# Full Name                                                                                                                                   0
# Department                                                                                                                                  0
# Semester                                                                                                                                    8
# In your opinion, does the current information architecture (layout of pages, menus, and modules) support user goals effectively?            0
# Is the system responsive across devices (desktop, tablet, mobile)?                                                                          0
# Does the system follow any standardized design principles (e.g., consistency, feedback, error handling)?                                    0
# Are there redundant or unused features that should be deprecated or redesigned?                                                             0
# Suggest one feature that would enhance the academic experience if added to the system.                                                     22
# Given that the system is accessible via specific IPs only (home & university), do you think this is a sufficient security mechanism?        0
# Do you feel your login credentials and academic records are securely handled by the system?                                                 0
# Should additional layers of security be implemented (e.g., OTP, 2FA, CAPTCHA)?                                                              0
# The system notify you if there is any unauthorized access or suspicious activity on your SIS account?                                       0
#  The system send you a notification whenever a teacher or instructor uploads a new assignment                                               0
# How would you rate the software’s reliability and uptime?                                                                                   0
# Does the system provide error messages and validation feedback that help users recover from mistakes?                                       0
# Do you think the system was developed with scalability in mind (e.g., handling load for growing students)?                                  0
# How effective is the system’s help/support documentation or assistance options?                                                             4
# How frequently do you interact with the SIS account system?                                                                                 0
#   Have you experienced performance issues (e.g., slow loading, timeouts) while using the system?                                            0
# From a user experience (UX) perspective, how would you rate the system's interface?                                                         0
# Which of the following modules do you actively use?                                                                                         0
# Do you think the content modules (e.g., Notice Board, Events) are being actively maintained and updated?                                    0
# Announcements and notification (course update, deadlines, etc) should be included                                                           2
# Column 25                                                                                                                                 103
# Status                                                                                                                                      1
# Column 25.1                                                                                                                               103
# @dropdown                                                                                                                                 103
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Column 25  Column 25.1  @dropdown
# count        0.0          0.0        0.0
# mean         NaN          NaN        NaN
# std          NaN          NaN        NaN
# min          NaN          NaN        NaN
# 25%          NaN          NaN        NaN
# 50%          NaN          NaN        NaN
# 75%          NaN          NaN        NaN
# max          NaN          NaN        NaN

# %%
df['Department'].value_counts()
# Out:
# Department
# Computer science                           26
# Computer Science                           13
# Computer Science                            9
# CS                                          5
# computer science                            4
# BSCS                                        3
# Computer science                            3
# BSAI                                        3
# Artificial intelligence                     2
# BBA                                         2
# bscs                                        2
# Bscs                                        2
# Artificial intelligence                     2
# Artificial Intelligence                     1
# Computer science (BSAI)                     1
# COMPUTER SCIENCE                            1
# Languages and cultural studies              1
# Software engineering                        1
# Computer Science (Ai)                       1
# Bsai                                        1
# CSSE(software engineering)                  1
# SOFTWARE ENGINEERING                        1
# Bs(AI)                                      1
# Business management and economics           1
# CSAI                                        1
# Artificial intelligence (cs)                1
# COMPUTER science                            1
# BS AI                                       1
# Bscs                                        1
# BsAi                                        1
# CS(Ai)                                      1
# Business Management and Economics           1
# BS Computer science                         1
# Business management and administration      1
# Bba                                         1
# Artificial intelligence (AI)                1
# Ai                                          1
# bs software engineering                     1
# Cs                                          1
# BS AI                                       1
# Name: count, dtype: int64
