# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;

# %%
months=[1,2,3,4]
sales=[1111,1000,30,4000]

# %%
plt.plot(months,sales,color="green",linestyle="--",linewidth=4,label="2025 Sales Data of University")
plt.xlabel("Moths")
plt.ylabel("Sales")
plt.title("2025 Sales Data")
plt.legend(loc="upper left",fontsize=12)
plt.show()
